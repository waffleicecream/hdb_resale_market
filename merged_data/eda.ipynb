# %%
import pandas as pd

df = pd.read_csv("[FINAL]hdb_with_amenities_macro_pre2026.csv")

# %%
df.head(3)
# Out:
#         month        town flat_type block       street_name storey_range  \
# 0  2021-01-01  ANG MO KIO    2 ROOM   170  ANG MO KIO AVE 4     01 TO 03
# 1  2021-01-01  ANG MO KIO    2 ROOM   170  ANG MO KIO AVE 4     07 TO 09
# 2  2021-01-01  ANG MO KIO    3 ROOM   331  ANG MO KIO AVE 1     04 TO 06
#
#    floor_area_sqm      flat_model  lease_commence_date    remaining_lease  \
# 0            45.0        Improved                 1986  64 years 01 month
# 1            45.0        Improved                 1986  64 years 01 month
# 2            68.0  New Generation                 1981           59 years
#
#    ...  num_primary_1km dist_nearest_park_m  \
# 0  ...                2               703.5
# 1  ...                2               703.5
# 2  ...                2               275.5
#
#                                            parks_1km  num_parks_1km  \
# 0  GELENGGANG PARK|LEBAN PARK|BISHAN-ANG MO KIO P...              4
# ...

# %%
df[df['month'].str.startswith('2025')].groupby(['flat_type'])["resale_price"].count()
# Out:
# flat_type
# 1 ROOM                  5
# 2 ROOM                832
# 3 ROOM               6151
# 4 ROOM              10843
# 5 ROOM               5781
# EXECUTIVE            1470
# MULTI-GENERATION        4
# Name: resale_price, dtype: int64
